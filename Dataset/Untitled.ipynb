# %%
import os
import pandas as pd

# %%
pokemon = pd.read_csv("pokemon.csv")
prev_name = ""

# %%
!
# Out:
# Untitled.ipynb big            pokemon.csv
# alt            extra          small

# %%
for x in range(len(pokemon)):
    if(pokemon['Name'][x][:len(prev_name)+4] != prev_name +"Mega" ):
        try:
            print(pokeo)
            os.rename("alt/"+pokemon['#'][x]+".png", "alt/"+pokemon['Name'][x]+".png")
            print("Need to rename!")
        except:
            print("x")
    prev_name = pokemon['Name'][x]
# Out:
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# x
# ...
